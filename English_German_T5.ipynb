# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration


checkpoint = 'google-t5/t5-small'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = T5ForConditionalGeneration.from_pretrained(checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
tokenizer.get_vocab().keys()
# Out:
# dict_keys(['▁intact', 'woche', '▁decorating', '▁împreună', '▁joi', 'kay', '▁charger', '▁dropped', '▁evening', '▁Herausforderung', '▁Echo', 'lum', '▁Farb', '▁yesterday', '▁chance', 'bau', '▁femeile', '▁carried', 'Surgical', 'quelles', 'cutaneous', '▁septembre', 'iocese', '▁sites', '▁uniquely', '▁meci', '▁demande', 'HR', '▁reply', '▁dank', '▁£10', 'endra', 'executing', '▁division', '▁Go', '▁ale', 'Wettbewerb', 'Infrastruktur', 'mettez', '▁spinal', 'NASDAQ', 'überall', 'boiled', '▁limitations', '▁Barry', '▁overcome', '▁MySQL', 'tate', '▁collègue', '▁customize', 'Black', '▁Wagen', '▁izolat', 'check', '▁Lan', '6%', 'batterie', '▁margin', 'ILL', '▁confidential', 'û', '▁animat', '▁Ci', '▁submit', 'born', 'nés', '▁Mazda', '▁fans', '▁DJ', '▁viața', '▁cercet', '▁explicitly', '▁citit', '▁tradițional', '▁entgegen', '▁système', '▁healthier', 'dan', 'nung', '▁2005', '1.000', 'ES', '▁factories', '▁Through', '▁tablet', 'Pol', '▁Starting', '▁chorus', 'schalten', 'BI', '▁Timişoara', '▁Encyclopedia', '▁proiecte', '▁dazu', '▁key', '▁Egypt', '▁Claire', '▁Iasi', '▁Artificial', '▁ständig', '▁knob', '▁authorization', 'ulph', '▁puisqu', '▁affair', '0.3', 'gent', 'veni', '▁vivre', '▁Obst', 'macher', 'fiinta', '▁Förderung', 'Serie', '▁Bank', '▁Derma', '▁portray', '▁tips', '▁minority', '▁looking', 'hal', '▁Plum', '▁Kä', 'plete', '▁toothpaste', '▁helicopter', '▁spécialisé', 'characterized', '▁Turk', '▁tooth', '▁Concrete', '▁metal', '▁nimeni', '▁Diagram', '▁fascinant', '▁fate', 'gehoben', '▁sensibil', 'CY', '▁Cherry', '▁pare', 'owed', 'collegiate', '▁Blade', '▁locati', '▁Jimmy', '▁teilnehmen', '▁distract', '▁Behandlung', 'luj', '▁Zoo', '▁Translat', 'ța', '▁ecosystem', '▁periodically', '▁ethical', '▁prieteni', '▁edge', '▁Conclusion', '▁Fer', '▁Berliner', '▁fastest', '▁sagte', 'zahlung', '▁children', '▁niveau', '▁darkness', 'chat', '7:30', 'UF', '▁consolid', '▁outils', '▁changed', '▁guest', '▁entstehen', '▁Sophia', '▁accompagn', '▁Find', '▁Größe', '▁Ukrainian', '▁jurisdiction', '▁Stein', '▁shaving', '▁tile', '▁resp', '▁devastated', '▁controlled', '▁creamy', '▁scade', '▁fly', '▁Burton', '▁Wert', 'ignon', '▁Zucker', '▁trouvai', '▁disponible', '▁autonome', '▁connectivity', '▁Kalender', '▁07', '▁south', '▁campagne', 'jon', '▁chaussure', '▁pretty', '▁vague', '▁marking', 'uca', 'că', '▁trails', '▁curat', '▁game', '▁fancy', '▁ankle', '▁stole', '▁abge', '▁Tavern', '▁Brad', '▁mushrooms', '▁12.', '▁Kennedy', '▁Polizei', '▁autoritățil', '▁amend', '▁rasch', '▁production', '▁vari', '▁illustrate', '▁historische', '1.6', 'nommée', '▁Nathan', 'bil', '▁ascuns', 'hik', '▁diagnostic', 'mitglied', '▁Indonesia', '▁Examination', 'ordinateur', '▁liabilities', '▁Stern', '▁quotation', '▁apropiere', 'wind', 'safe', '▁awards', '▁Convention', 'fäl', '▁nutritious', '▁plăcere', '▁Therapy', '▁plein', 'appro', '▁invalid', '▁convers', '▁Suffolk', '▁detailed', '▁Juan', '▁retailer', 'druck', '▁saturated', '▁verfügt', 'ic', '▁wicked', '▁effortlessly', '▁Small', 'likewise', '▁Ar', 'flakes', '▁Hidden', '▁defense', '▁Soft', '▁abdominal', 'M', '▁Podcast', '▁Justice', '▁Performance', 'WOOD', '▁1985', '▁utilisateurs', '30', '▁conven', '▁Studien', '▁independent', '▁forefront', '510', '▁italian', '▁Technology', '▁Brasov', 'originating', 'NK', '▁restrict', 'olin', '▁schwierig', '▁estate', 'Eventually', '▁Reagan', '▁Shower', '▁question', '▁illegal', '▁aceasta', '▁Luci', '“', '▁sausage', 'conferencing', '▁recognize', '▁Sounds', '▁pictures', 'ет', '▁knee', '▁occur', '▁heal', '▁bevor', '▁Aluminium', '▁bancar', '▁martyr', 'éclat', 'local', 'usch', '▁1920', '▁denomination', '141', '▁Before', '▁consultation', '▁occasions', 'ulescu', '▁Procedure', '▁dialect', 'Alors', 'aiba', '▁Erdogan', '▁finger', '▁exerc', '▁Cutting', '▁Pru', '▁erlaubt', 'un', 'rennen', '▁musicians', '▁widow', 'uvent', 'oarelor', 'effort', '▁blush', '▁royal', '▁freezer', '▁chord', 'mati', '▁Dienstleistung', '=', '▁Direction', '▁something', 'tension', '▁chapters', '▁technicians', '▁cake', '▁Inter', '▁présenter', '▁Fitness', '▁1993', '▁matrix' ...

# %%
# training
input_ids = tokenizer("The <extra_id_0> walks in <extra_id_1> park", return_tensors="pt").input_ids
labels = tokenizer("<extra_id_0> cute dog <extra_id_1> the <extra_id_2>", return_tensors="pt").input_ids
outputs = model(input_ids=input_ids, labels=labels)
loss = outputs.loss
logits = outputs.logits

# %%
input_ids = tokenizer(
    "translate English to German: This is really good ", return_tensors="pt"
).input_ids  # Batch size 1
outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Das ist wirklich gut.
